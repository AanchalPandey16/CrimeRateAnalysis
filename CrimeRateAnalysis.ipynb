# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Crime_data.csv')
print(df)
# Out:
#       Year              State       District  Rape Cases  Abduction Cases  \
# 0     2018                Goa  Vasco da Gama          21              125
# 1     2019         Tamil Nadu     Coimbatore         136              114
# 2     2019     Madhya Pradesh        Gwalior         133              178
# 3     2021            Haryana        Panipat         102              216
# 4     2020            Tripura       Agartala         100              259
# ...    ...                ...            ...         ...              ...
# 2995  2019            Mizoram       Champhai         139              150
# 2996  2019          Telangana       Warangal          19              300
# 2997  2021  Arunachal Pradesh       Itanagar          22              136
# 2998  2021            Manipur  Churachandpur          58              218
# 2999  2018      Daman and Diu     Vijayawada          75              277
#
#       Murder Cases  Total Crimes Population  Crime Rate  Arrests  \
# 0               38           355     601856       58.98      294
# 1               76           730     454251      160.70      627
# 2               71           748    1881680       39.75      549
# 3               25           558     725939       76.87      435
# 4               75           487    1630786       29.86      363
# ...            ...           ...        ...         ...      ...
# 2995             7           778     980131       79.38      620
# 2996            72           833     685975      121.43      661
# 2997            20           439     677041       64.84      316
# 2998            56           777    1970611       39.43      462
# 2999            56           905     390783      231.59      847
#
#       Crime Clearance Rate
# 0                    82.82
# 1                    85.89
# 2                   273.40
# 3                    77.96
# 4                    74.54
# ...                    ...
# 2995                 79.69
# 2996                 79.35
# 2997                 71.98
# 2998                 59.46
# 2999                 93.59
#
# [3000 rows x 11 columns]

# %%
#To take a look at the first five rows as default
df.head()
# Out:
#    Year           State       District  Rape Cases  Abduction Cases  \
# 0  2018             Goa  Vasco da Gama          21              125
# 1  2019      Tamil Nadu     Coimbatore         136              114
# 2  2019  Madhya Pradesh        Gwalior         133              178
# 3  2021         Haryana        Panipat         102              216
# 4  2020         Tripura       Agartala         100              259
#
#    Murder Cases  Total Crimes  Population  Crime Rate  Arrests  \
# 0            38           355      601856       58.98      294
# 1            76           730      454251      160.70      627
# 2            71           748     1881680       39.75      549
# 3            25           558      725939       76.87      435
# 4            75           487     1630786       29.86      363
#
#    Crime Clearance Rate
# 0                 82.82
# 1                 85.89
# 2                 73.40
# 3                 77.96
# 4                 74.54

# %%
#To take a look at the last five rows as default
df.tail()
# Out:
#       Year              State       District  Rape Cases  Abduction Cases  \
# 2995  2019            Mizoram       Champhai         139              150
# 2996  2019          Telangana       Warangal          19              300
# 2997  2021  Arunachal Pradesh       Itanagar          22              136
# 2998  2021            Manipur  Churachandpur          58              218
# 2999  2018     Andhra Pradesh     Vijayawada          75              277
#
#       Murder Cases  Total Crimes  Population  Crime Rate  Arrests  \
# 2995             7           778      980131       79.38      620
# 2996            72           833      685975      121.43      661
# 2997            20           439      677041       64.84      316
# 2998            56           777     1970611       39.43      462
# 2999            56           905      390783      231.59      847
#
#       Crime Clearance Rate
# 2995                 79.69
# 2996                 79.35
# 2997                 71.98
# 2998                 59.46
# 2999                 93.59

# %%
#print the summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  3000 non-null   int64
#  1   State                 3000 non-null   object
#  2   District              3000 non-null   object
#  3   Rape Cases            3000 non-null   int64
#  4   Abduction Cases       3000 non-null   int64
#  5   Murder Cases          3000 non-null   int64
#  6   Total Crimes          3000 non-null   int64
#  7   Population            3000 non-null   int64
#  8   Crime Rate            3000 non-null   float64
#  9   Arrests               3000 non-null   int64
#  10  Crime Clearance Rate  3000 non-null   float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 257.9+ KB

# %%
#To know the total number of rows and columns in the data set
df.shape
# Out:
# (3000, 11)

# %%
# Shows basic statistics for each numerical column in the DataFrame
df.describe()
# Out:
#               Year   Rape Cases  Abduction Cases  Murder Cases  Total Crimes  \
# count  3000.000000  3000.000000      3000.000000   3000.000000   3000.000000
# mean   2019.987667   105.591000       158.363333     53.326333    592.809333
# std       1.404578    55.567271        82.425979     27.673256    168.284082
# min    2018.000000    10.000000        20.000000      5.000000    139.000000
# 25%    2019.000000    56.750000        86.000000     29.000000    472.000000
# 50%    2020.000000   107.000000       158.000000     53.000000    590.000000
# 75%    2021.000000   153.000000       229.000000     77.000000    716.250000
# max    2022.000000   200.000000       300.000000    100.000000   1043.000000
#
#          Population   Crime Rate      Arrests  Crime Clearance Rate
# count  3.000000e+03  3000.000000  3000.000000           3000.000000
# mean   1.011891e+06   112.226880   446.870000             75.267830
# std    5.660212e+05   152.843849   157.174832             14.394948
# min    5.052100e+04     9.920000    89.000000             49.810000
# 25%    5.189772e+05    38.820000   333.000000             62.655000
# 50%    1.014048e+06    59.400000   433.000000             75.170000
# 75%    1.497903e+06   114.862500   547.000000             87.902500
# max    1.997838e+06  1706.020000  1019.000000            100.000000

# %%
#printing the value distribution
print(df['District'].value_counts())
# Out:
# District
# Udaipur      67
# Raipur       38
# Madurai      38
# Bengaluru    38
# Daman        36
#              ..
# Margao       22
# Nainital     22
# Gwalior      21
# Durg         19
# Silvassa     15
# Name: count, Length: 104, dtype: int64

# %%
#removing Nan Value or missing values
df.dropna()
# Out:
#       Year              State       District  Rape Cases  Abduction Cases  \
# 0     2018                Goa  Vasco da Gama          21              125
# 1     2019         Tamil Nadu     Coimbatore         136              114
# 2     2019     Madhya Pradesh        Gwalior         133              178
# 3     2021            Haryana        Panipat         102              216
# 4     2020            Tripura       Agartala         100              259
# ...    ...                ...            ...         ...              ...
# 2995  2019            Mizoram       Champhai         139              150
# 2996  2019          Telangana       Warangal          19              300
# 2997  2021  Arunachal Pradesh       Itanagar          22              136
# 2998  2021            Manipur  Churachandpur          58              218
# 2999  2018     Andhra Pradesh     Vijayawada          75              277
#
#       Murder Cases  Total Crimes  Population  Crime Rate  Arrests  \
# 0               38           355      601856       58.98      294
# 1               76           730      454251      160.70      627
# 2               71           748     1881680       39.75      549
# 3               25           558      725939       76.87      435
# 4               75           487     1630786       29.86      363
# ...            ...           ...         ...         ...      ...
# 2995             7           778      980131       79.38      620
# 2996            72           833      685975      121.43      661
# 2997            20           439      677041       64.84      316
# 2998            56           777     1970611       39.43      462
# 2999            56           905      390783      231.59      847
#
#       Crime Clearance Rate
# 0                    82.82
# 1                    85.89
# 2                    73.40
# 3                    77.96
# 4                    74.54
# ...                    ...
# 2995                 79.69
# 2996                 79.35
# 2997                 71.98
# 2998                 59.46
# 2999                 93.59
#
# [3000 rows x 11 columns]

# %%
#Printing the no of duplicate rows
print(df.duplicated().sum())
#remove duplicate rows
df.drop_duplicates()
# Out:
# 0
#       Year              State       District  Rape Cases  Abduction Cases  \
# 0     2018                Goa  Vasco da Gama          21              125
# 1     2019         Tamil Nadu     Coimbatore         136              114
# 2     2019     Madhya Pradesh        Gwalior         133              178
# 3     2021            Haryana        Panipat         102              216
# 4     2020            Tripura       Agartala         100              259
# ...    ...                ...            ...         ...              ...
# 2995  2019            Mizoram       Champhai         139              150
# 2996  2019          Telangana       Warangal          19              300
# 2997  2021  Arunachal Pradesh       Itanagar          22              136
# 2998  2021            Manipur  Churachandpur          58              218
# 2999  2018     Andhra Pradesh     Vijayawada          75              277
#
#       Murder Cases  Total Crimes  Population  Crime Rate  Arrests  \
# 0               38           355      601856       58.98      294
# 1               76           730      454251      160.70      627
# 2               71           748     1881680       39.75      549
# 3               25           558      725939       76.87      435
# 4               75           487     1630786       29.86      363
# ...            ...           ...         ...         ...      ...
# 2995             7           778      980131       79.38      620
# 2996            72           833      685975      121.43      661
# 2997            20           439      677041       64.84      316
# 2998            56           777     1970611       39.43      462
# 2999            56           905      390783      231.59      847
#
#       Crime Clearance Rate
# 0                    82.82
# 1                    85.89
# 2                    73.40
# 3                    77.96
# 4                    74.54
# ...                    ...
# 2995                 79.69
# 2996                 79.35
# 2997                 71.98
# 2998                 59.46
# 2999                 93.59
#
# [3000 rows x 11 columns]

# %%
#counting all null values
df.isnull().sum()
# Out:
# Year                    0
# State                   0
# District                0
# Rape Cases              0
# Abduction Cases         0
# Murder Cases            0
# Total Crimes            0
# Population              0
# Crime Rate              0
# Arrests                 0
# Crime Clearance Rate    0
# dtype: int64

# %%
# Create a condition to filter rows where the 'District' column has the value 'Mumbai'
condition = df['District'] == 'Mumbai'

# Filter the DataFrame using the condition; this returns all rows where 'District' is 'Mumbai'
df[condition]

# Display only the first 5 rows of the filtered DataFrame
df[condition].head(5)
# Out:
#      Year        State District  Rape Cases  Abduction Cases  Murder Cases  \
# 10   2021  Maharashtra   Mumbai          33              178             7
# 48   2022  Maharashtra   Mumbai         142              118            83
# 55   2019  Maharashtra   Mumbai          46              216            19
# 68   2020  Maharashtra   Mumbai         113              287            84
# 172  2019  Maharashtra   Mumbai         117              127            25
#
#      Total Crimes Population  Crime Rate  Arrests  Crime Clearance Rate
# 10            643    1558180       41.27     1381                259.25
# 48            765    1235640       61.91      676                 88.37
# 55            442    1597310       27.67      253                 57.24
# 68            829     168275      492.65      812                 97.95
# 172           367     771078       47.60      356                 97.00

# %%
#Count unique values
df.nunique()
# Out:
# Year                       5
# State                     40
# District                 104
# Rape Cases               196
# Abduction Cases          281
# Murder Cases              96
# Total Crimes             723
# Population              2997
# Crime Rate              2693
# Arrests                  687
# Crime Clearance Rate    2236
# dtype: int64

# %%
# find the 5 states with the lowest crime rates
df.sort_values(by="Crime Rate").head(5)
# Out:
#       Year           State     District  Rape Cases  Abduction Cases  \
# 1226  2020       Telangana    Nizamabad          77               26
# 1755  2018         Tripura  Kailashahar          27               38
# 2560  2019      Puducherry     Karaikal          15               99
# 1849  2019  Madhya Pradesh       Bhopal          53               29
# 981   2020          Punjab     Amritsar          10               95
#
#       Murder Cases  Total Crimes Population  Crime Rate  Arrests  \
# 1226            25           196    1975935        9.92      179
# 1755            17           206    1905690       10.81      177
# 2560            17           196    1787360       10.97      141
# 1849            64           205    1827005       11.22     1119
# 981             18           220    1853314       11.87      211
#
#       Crime Clearance Rate
# 1226                 91.33
# 1755                 85.92
# 2560                 71.94
# 1849                 58.05
# 981                  95.91

# %%
# get the 5 states with the highest crime rates.
df.sort_values(by="Crime Rate").tail(5)
# Out:
#       Year             State   District  Rape Cases  Abduction Cases  \
# 1541  2020             Bihar       Gaya         103              288
# 1470  2021  Himachal Pradesh      Mandi         168              155
# 78    2018         Karnataka  Mangaluru         157              253
# 971   2022           Gujarat   Vadodara         172              288
# 81    2021            Kerala   Silvassa        1192              286
#
#       Murder Cases  Total Crimes Population  Crime Rate  Arrests  \
# 1541            84           834      62537     1333.61      620
# 1470            31           835      61868     1349.65      441
# 78              23           810     188296     1430.17      581
# 971             82          1016      70493     1441.28      906
# 81               9           888      52051     1706.02      761
#
#       Crime Clearance Rate
# 1541                 74.34
# 1470                 52.81
# 78                   71.73
# 971                  89.17
# 81                   85.70

# %% [markdown]
# #Question 1: What is the total number of rape cases in a following years?

# %%
plt.figure(figsize=(7, 4))
# Group the dataset by 'Year' and calculate the sum of 'Rape Cases' for each year
rape_cases_trend = df.groupby('Year')['Rape Cases'].sum()

# Plot the line chart showing the trend of total rape cases per year
sns.lineplot(x=rape_cases_trend.index, y=rape_cases_trend.values, marker='o', color='Purple', linewidth=2)

# Title and labels for the plot
plt.title("Total Rape Cases per Year")
plt.xlabel("Year")
plt.ylabel("Total Rape Cases")

# Show the plot
plt.show()

# %% [markdown]
# # Question 2: Which state has the highest crime rate?

# %%
plt.figure(figsize=(7, 4))

# Sort the dataset by 'Crime Rate' in descending order and get the top 10 states
top_states_by_crime_rate = df.sort_values('Crime Rate', ascending=False).head(10)

# Create a bar plot to visualize the top 10 states by crime rate
sns.barplot(x='Crime Rate', y='State', data=top_states_by_crime_rate, color='#C3B1E1')

# Set title and labels for the plot
plt.title("Top States by Crime Rate")
plt.xlabel("Crime Rate")  # Label for the x-axis (Crime Rate)
plt.ylabel("State")  # Label for the y-axis (States)

# Display the plot
plt.show()

# %% [markdown]
# # Question 3: What is the correlation between total crimes and population?

# %%
plt.figure(figsize=(8, 4))
# Create a scatter plot with Population on the x-axis and Total Crimes on the y-axis
sns.scatterplot(x='Population', y='Total Crimes', data=df, hue='State', size='Total Crimes', sizes=(20, 200), palette="Purples", legend=False)

# Set title and labels for the plot
plt.title("Total Crimes vs. Population")
plt.xlabel("Population")
plt.ylabel("Total Crimes")

# Show the plot
plt.show()

# %% [markdown]
# # Question 4: What is the average crime clearance rate vary across different states?

# %%
plt.figure(figsize=(10, 5))
# Group the data by 'State' and calculate the mean 'Crime Clearance Rate' for each state, then sort them in descending order
state_avg_clearance_rate = df.groupby('State')['Crime Clearance Rate'].mean().sort_values(ascending=False).head(20)

# Create a bar plot using the calculated average crime clearance rates
sns.barplot(x=state_avg_clearance_rate.index, y=state_avg_clearance_rate.values, color='#C3B1E1', dodge=False)

# Set the title and labels for the plot
plt.title("Average Crime Clearance Rate by State")
plt.xlabel("State")
plt.ylabel("Average Crime Clearance Rate")

# Rotate x-axis labels (state names) to avoid overlap and ensure readability0
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# # Question 5: What is the distribution of abduction cases in western states?

# %%
# Defining the western states
western_states = ['Goa', 'Gujarat', 'Maharashtra', 'Rajasthan']

# Filtering the dataset for western states
western_states_df = df[df['State'].isin(western_states)]

# Plot the boxplot for Abduction Cases in Western States
plt.figure(figsize=(12, 6))
sns.boxplot(x='State', y='Abduction Cases', data=western_states_df, color='#C3B1E1')

plt.title("Distribution of Abduction Cases in Western States")
plt.xlabel("State")
plt.ylabel("Abduction Cases")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 6: What is the trend in the number of murder cases over the years?

# %%
murder_trend = df.groupby('Year')['Murder Cases'].sum()
plt.figure(figsize=(8, 5))

# Create a line plot with murder cases trend
sns.lineplot(x=murder_trend.index, y=murder_trend.values, marker='o', color='#C3B1E1', linestyle='--', linewidth=2)

# Set the title and labels for the plot
plt.title("Trend in Murder Cases Over Years")
plt.xlabel('Year')
plt.ylabel('Murder Cases')

# Show the plot
plt.show()

# %% [markdown]
# # Question 7: Which state has the highest total number of arrests?

# %%
plt.figure(figsize=(10, 6))

#pick top 10 district
top_districts = df.sort_values(by='Arrests', ascending=False).head(10)

#barplot for the top 10 districts
sns.barplot(x='Arrests', y='State', data=top_districts, color='#C3B1E1')

# Set the title and labels
plt.title("Top 10 Districts with Highest Number of Arrests")
plt.xlabel("Number of Arrests")
plt.ylabel("District")
plt.show()

# %% [markdown]
# # Question 8: What is the average crime rate across southern states over the years?

# %%
#Southern States
southern_states = ['Andhra Pradesh', 'Telangana', 'Tamil Nadu', 'Karnataka', 'Kerala', 'Puducherry']

# Filter the dataset for Southern States
southern_states_df = df[df['State'].isin(southern_states)]

# Calculate the average crime rate by state and year
avg_crime_rate_by_state = southern_states_df.groupby(['Year', 'State'])['Crime Rate'].mean().reset_index()

# Plot the line plot for Southern States
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Crime Rate', hue='State', data=avg_crime_rate_by_state, palette='cool', marker='o')

# Set title and labels
plt.title("Average Crime Rate Across Southern States Over the Years")
plt.xlabel("Year")
plt.ylabel("Average Crime Rate")
plt.legend(title='State')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# # Question 9:  Calculate the total number of cases for each crime type

# %%
import matplotlib.pyplot as plt

# Sum the cases for each crime type
crime_type_counts = df[['Rape Cases', 'Abduction Cases', 'Murder Cases']].sum()

# Plot the donut chart
plt.figure(figsize=(8, 6))
plt.pie(crime_type_counts, labels=crime_type_counts.index, autopct='%1.1f%%', colors=['#9b8cc4', '#6f4c9e', '#b5a0d0'], wedgeprops=dict(width=0.4))

# Set the title
plt.title("Crime Type Distribution")

# Show the plot
plt.show()

# %% [markdown]
# # Question 10: Correlation Matrix of Crime Data

# %%
# Ensure the relevant columns are numeric
numeric_columns = df[['Rape Cases', 'Abduction Cases', 'Murder Cases', 'Total Crimes', 'Population', 'Crime Rate', 'Arrests']]

# Convert columns to numeric, forcing errors to NaN
numeric_columns = numeric_columns.apply(pd.to_numeric, errors='coerce')

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Set up the visual style of the plot
plt.figure(figsize=(10, 5))  # Adjust the size to make the plot clearer
sns.set(style='white')  # Use a clean white background

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='Purples', fmt='.2f', linewidths=0.8, vmin=-1, vmax=1,
            cbar_kws={'label': 'Correlation Coefficient'}, square=True)

# Set the title
plt.title("Correlation Matrix of Crime Data", fontsize=16)

# Display the plot
plt.show()
